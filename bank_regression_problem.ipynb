# %%
# Load the dataset 
import pandas as pd

data=pd.read_csv(r"D:\datasets\Banking analyse\syntheticbank_data.xls")
#dataset preview
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0       19114.12            1824.843333                3.0  ...
# 1       19114.12            1824.843333                3.0  ...
# 2       19114.12            1824.843333                3.0  ...
# 3       19114.12            1824.843333                3.0  ...
# 4       19114.12            1824.843333                3.0  ...
#
#    Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0               265.0                     No            49.574949
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        3000 non-null   int64
#  1   Customer_ID               3000 non-null   int64
#  2   Month                     3000 non-null   int64
#  3   Name                      3000 non-null   object
#  4   Age                       3000 non-null   float64
#  5   SSN                       3000 non-null   float64
#  6   Occupation                3000 non-null   object
#  7   Annual_Income             3000 non-null   float64
#  8   Monthly_Inhand_Salary     3000 non-null   float64
#  9   Num_Bank_Accounts         3000 non-null   float64
#  10  Num_Credit_Card           3000 non-null   float64
#  11  Interest_Rate             3000 non-null   float64
#  12  Num_of_Loan               3000 non-null   float64
# ...

# %% [raw]
# Based on the problem statement, the important and necessary columns for the Performance Prediction (Regression) task are:
# Asset Growth: This is the target variable for the regression model, which predicts the growth of assets for the banking institution.
# Revenue: This is another target variable for the regression model, which predicts the revenue of the banking institution.
# Profitability: This is the third target variable for the regression model, which predicts the profitability of the banking institution.
# Annual_Income: This column is likely to have a significant impact on the bank's performance, as it reflects the income of the customers.
# Monthly_Inhand_Salary: This column may also have an impact on the bank's performance, as it reflects the income of the customers.
# Num_Bank_Accounts: This column may be useful in predicting the bank's performance, as it reflects the number of accounts held by customers.
# Num_Credit_Card: This column may also be useful in predicting the bank's performance, as it reflects the number of credit cards held by customers.
# Interest_Rate: This column may have an impact on the bank's performance, as it reflects the interest rates offered by the bank.
# Num_of_Loan: This column may also have an impact on the bank's performance, as it reflects the number of loans issued by the bank.
# Credit_Utilization_Ratio: This column may be useful in predicting the bank's performance, as it reflects the ratio of credit utilization to credit limit.
# Credit_History_Age: This column may also be useful in predicting the bank's performance, as it reflects the age of the credit history.
# Monthly_Balance: This column may have an impact on the bank's performance, as it reflects the average monthly balance of the customers.
# These columns are likely to be important for predicting the key performance indicators (KPIs) for the banking institution, such as asset growth, revenue, and profitability.

# %%
# Select the important and necessary columns
important_columns = ['Asset Growth', 'Revenue', 'Profitability', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Monthly_Balance']

# Create a new DataFrame with the selected columns
df = data[important_columns]

# Print the shape of the new DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Asset Growth              3000 non-null   int64
#  1   Revenue                   3000 non-null   int64
#  2   Profitability             3000 non-null   int64
#  3   Annual_Income             3000 non-null   float64
#  4   Monthly_Inhand_Salary     3000 non-null   float64
#  5   Num_Bank_Accounts         3000 non-null   float64
#  6   Num_Credit_Card           3000 non-null   float64
#  7   Interest_Rate             3000 non-null   float64
#  8   Num_of_Loan               3000 non-null   float64
#  9   Credit_Utilization_Ratio  3000 non-null   float64
#  10  Credit_History_Age        3000 non-null   float64
#  11  Monthly_Balance           3000 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 281.4 KB

# %%
df.describe()
# Out:
#        Asset Growth      Revenue  Profitability  Annual_Income  \
# count   3000.000000  3000.000000    3000.000000    3000.000000
# mean      50.546667   500.139667      24.609000   51571.814413
# std       29.002026   287.729847      14.833637   39357.531475
# min        0.000000     1.000000       0.000000    7103.035000
# 25%       26.000000   262.000000      12.000000   19310.620000
# 50%       51.000000   500.500000      24.000000   35547.710000
# 75%       75.000000   746.250000      38.000000   72559.360000
# max      100.000000  1000.000000      50.000000  177150.400000
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count            3000.000000        3000.000000      3000.000000
# mean             4295.870982           5.404000         5.385333
# std              3261.817044           2.675912         1.984649
# min               468.770000           0.000000         1.000000
# 25%              1683.901667           3.000000         4.000000
# ...

# %%
df.shape
# Out:
# (3000, 12)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


feature_columns = ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 
                   'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 
                   'Credit_Utilization_Ratio', 'Credit_History_Age', 'Monthly_Balance']

# Create a figure with subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Plotting Asset Growth vs. Feature Columns
for i, column in enumerate(feature_columns):
    row = i // 3
    col = i % 3
    sns.scatterplot(data=df, x=column, y='Asset Growth', ax=axes[row, col])
    axes[row, col].set_title(f'Asset Growth vs. {column}')
    axes[row, col].set_xlabel(column)
    axes[row, col].set_ylabel('Asset Growth')

plt.tight_layout()
plt.show()

# %%
# Create a figure with subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Plotting Revenue vs. Feature Columns
for i, column in enumerate(feature_columns):
    row = i // 3
    col = i % 3
    sns.scatterplot(data=df, x=column, y='Revenue', ax=axes[row, col])
    axes[row, col].set_title(f'Revenue vs. {column}')
    axes[row, col].set_xlabel(column)
    axes[row, col].set_ylabel('Revenue')

plt.tight_layout()
plt.show()

# %%
# Create a figure with subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Plotting Profitability vs. Feature Columns
for i, column in enumerate(feature_columns):
    row = i // 3
    col = i % 3
    sns.scatterplot(data=df, x=column, y='Profitability', ax=axes[row, col])
    axes[row, col].set_title(f'Profitability vs. {column}')
    axes[row, col].set_xlabel(column)
    axes[row, col].set_ylabel('Profitability')

plt.tight_layout()
plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')

plt.show()

# %%
df.columns
# Out:
# Index(['Asset Growth', 'Revenue', 'Profitability', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Credit_Utilization_Ratio',
#        'Credit_History_Age', 'Monthly_Balance'],
#       dtype='object')

# %%
#Select the feature columns
feature_columns = ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 
                   'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 
                   'Credit_Utilization_Ratio', 'Credit_History_Age', 'Monthly_Balance']

# Select the target columns
target_columns = ['Asset Growth', 'Revenue', 'Profitability']

# Create separate DataFrames for features and targets
features = df[feature_columns]
target = df[target_columns]

# Display the first few rows of each DataFrame
print("Features:")
features.head()
# Out:
# Features:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  Credit_Utilization_Ratio  Credit_History_Age  \
# 0            3.0          4.0                 26.822620               265.0
# 1            3.0          4.0                 31.944960               266.0
# 2            3.0          4.0                 28.609352               267.0
# 3            3.0          4.0                 31.377862               268.0
# 4            3.0          4.0                 24.797347               269.0
#
#    Monthly_Balance
# 0       312.494089
# ...

# %%
print("\nTargets:")
target.head()
# Out:
# Targets:
#    Asset Growth  Revenue  Profitability
# 0            20      460             25
# 1            14      872             41
# 2            68      300              9
# 3            67      155             42
# 4            88      440             32

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error


# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Initialize models
models = {
    'Decision Tree': MultiOutputRegressor(DecisionTreeRegressor(random_state=42)),
    'Random Forest': MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42)),
    'XGBoost': xgb.XGBRegressor(objective='reg:squarederror', n_estimators=200, max_depth=10, learning_rate=0.01, colsample_bytree=0.8, subsample=1.0),
    'SVR': MultiOutputRegressor(SVR(kernel='rbf'))
}

# Train and evaluate models
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred, multioutput='raw_values')
    print(f"{name} Regressor Mean Squared Errors:")
    print(f"Asset Growth: {mse[0]}")
    print(f"Revenue: {mse[1]}")
    print(f"Profitability: {mse[2]}\n")
# Out:
# Decision Tree Regressor Mean Squared Errors:
# Asset Growth: 1889.1433333333334
# Revenue: 164091.80166666667
# Profitability: 374.62
#
# Random Forest Regressor Mean Squared Errors:
# Asset Growth: 972.2976743333332
# Revenue: 90262.8755545
# Profitability: 219.41565233333338
#
# XGBoost Regressor Mean Squared Errors:
# Asset Growth: 1373.6490948714024
# Revenue: 83111.06728899908
# Profitability: 726.9782819280415
#
# SVR Regressor Mean Squared Errors:
# Asset Growth: 913.6606606265397
# Revenue: 81722.79898739568
# Profitability: 208.53836569725246

# %% [raw]
# Conclusion:
# The SVR Regressor shows the best performance overall, achieving the lowest MSE for Asset Growth, Revenue, and Profitability compared to the other models.
#
# The Random Forest Regressor also performs well, especially for Asset Growth and Profitability, and is very close to SVR's performance.
#
# Therefore, based on these results, the SVR Regressor would be the preferred choice, followed by the Random Forest Regressor. Here is how you can interpret and use these results:
#
# SVR Regressor should be the primary model for predicting the KPIs (Asset Growth, Revenue, Profitability) as it generally provides the most accurate predictions.
# Random Forest Regressor can be used as a secondary model, providing a good balance between performance and interpretability.
# You may also consider further hyperparameter tuning and cross-validation for SVR to potentially improve its performance even more. Additionally, analyzing feature importance from the Random Forest model can provide insights into which features are most impactful for each KPI.

# %%
import numpy as np
import pandas as pd
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.metrics import mean_squared_error

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.33, random_state=42)

# Defining the parameter grid for SVR
param_grid = {
    'estimator__C': [0.1, 1, 10, 100],
    'estimator__gamma': [0.001, 0.01, 0.1, 1],
    'estimator__epsilon': [0.1, 0.2, 0.5, 0.3]
}

# Creating the SVR model wrapped in MultiOutputRegressor
svr = MultiOutputRegressor(SVR())

# Creating KFold cross-validation object
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Creating GridSearchCV object with cross-validation
grid_search = GridSearchCV(svr, param_grid, cv=kf, scoring='neg_mean_squared_error', verbose=3, n_jobs=-1)

# Fitting the GridSearchCV object to the training data
grid_search.fit(X_train, y_train)

# Extracting the best parameters and the best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print(f"Best parameters: {best_params}")

# Making predictions on the test data
y_pred = best_model.predict(X_test)

# Calculating and printing the mean squared errors for each target
mse_asset_growth = mean_squared_error(y_test['Asset Growth'], y_pred[:, 0])
mse_revenue = mean_squared_error(y_test['Revenue'], y_pred[:, 1])
mse_profitability = mean_squared_error(y_test['Profitability'], y_pred[:, 2])

print(f"Mean Squared Error for Asset Growth: {mse_asset_growth}")
print(f"Mean Squared Error for Revenue: {mse_revenue}")
print(f"Mean Squared Error for Profitability: {mse_profitability}")
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Best parameters: {'estimator__C': 1, 'estimator__epsilon': 0.5, 'estimator__gamma': 1}
# Mean Squared Error for Asset Growth: 848.1425271619473
# Mean Squared Error for Revenue: 80171.75327637779
# Mean Squared Error for Profitability: 218.6375274043268

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Defining the SVR model with the best parameters
svr_best = MultiOutputRegressor(SVR(C=1, epsilon=0.5, gamma=1))

# Fitting the SVR model with the best parameters to the training data
svr_best.fit(X_train, y_train)

# Making predictions on the test data
y_pred = svr_best.predict(X_test)

# Calculating and printing the mean squared errors for each target
mse_asset_growth = mean_squared_error(y_test['Asset Growth'], y_pred[:, 0])
mse_revenue = mean_squared_error(y_test['Revenue'], y_pred[:, 1])
mse_profitability = mean_squared_error(y_test['Profitability'], y_pred[:, 2])

print(f"Mean Squared Error for Asset Growth: {mse_asset_growth}")
print(f"Mean Squared Error for Revenue: {mse_revenue}")
print(f"Mean Squared Error for Profitability: {mse_profitability}")
# Out:
# Mean Squared Error for Asset Growth: 848.1425271619473
# Mean Squared Error for Revenue: 80171.75327637779
# Mean Squared Error for Profitability: 218.6375274043268

# %%
import pickle

# Save the trained SVR model
with open('bank_svr_model.pkl', 'wb') as file:
    pickle.dump(svr_best, file)

print("model saved")
# Out:
# model saved
